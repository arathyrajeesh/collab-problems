# %% [markdown]
# <a href="https://colab.research.google.com/github/arathyrajeesh/collab-problems/blob/main/basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = [10, 20, 30, 40, 50]

total = sum(a)

print("Sum:", total)
# Out:
# Sum: 150

# %%
a = [1, 2, 3, 4, 5]

a.reverse()

print( a)
# Out:
# [5, 4, 3, 2, 1]

# %%
a=('a','b','c','d','g')
list1=list(a)
list1[1]='k'
a=tuple(list1)
print(a)
# Out:
# ('a', 'k', 'c', 'd', 'g')

# %%
a=int(input('enter'))
